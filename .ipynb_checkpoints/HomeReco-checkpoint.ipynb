# %% [markdown]
# # HomeScraper

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Ouest France Immo

# %%
def ouest_france():
    
    def find_price(val):
        return val.find(class_="annPrix").text.strip().replace("\xa0", "").replace(" ", "").replace("€", "")

    def find_city(val):
        return val.find(class_="annVille").text

    def find_crit(val):
        return val.find(class_="annCriteres").text.strip()

    URL = 'https://www.ouestfrance-immo.com/acheter/maison/?lieux=12982,12984,13060,13176,12983,12959&vueMer=1'
    page = requests.get(URL)
    
    soup = BeautifulSoup(page.content, 'html.parser')
    results= soup.find(id="blocListAnnonces")
    bloc_res = results.find_all(class_='annLink')
    fix='https://www.ouestfrance-immo.com'
    
    all_val = []

    for val in results.find_all(class_='annLink', href=True):
        my_list = []

        my_list.append(find_price(val))
        my_list.append(find_city(val))
        crit = find_crit(val)
        surf=int(crit.split("|")[0].replace("m² ", ""))
        chb=int(crit.split("|")[1].replace("chb", ""))
        sdb=crit.split("|")[2].replace("sdb", "")

        my_list.append(surf)
        my_list.append(chb)
        my_list.append(sdb)

        my_list.append(val.find('img')['data-original'])
        my_list.append(fix+val['href'])

        page = requests.get(fix+val['href'])
        soup = BeautifulSoup(page.content, 'html.parser')
        results2 = soup.find_all('ul')

        terrain = soup.find_all('li')
        for val in terrain:

            if "Surf. terrain" in str(val):
                val = int(str(val).split("<strong>")[1].split("</strong>")[0].replace("m²", "").strip().replace(" ", ""))
                my_list.append(val)

        photos=results2[6]

        list_photos = []

        for pic in photos:
            if pic != '\n':
                list_photos.append(str(pic).split("src=")[1].split(" title=")[0])
        my_list.append(list_photos)
        all_val.append(my_list)
    
    df_of = pd.DataFrame(all_val)
    df_of.columns=["Prix", "Ville", "Surface", "Chambres", "Sdb", "Couverture", "Lien", "Terrain", "Photos"]
    df_of['VueMer'] = "Oui"
    df_of['Site'] = "OuestFrance"
    
    return df_of

# %%
df_of = ouest_france()
df_of
# Out:
#      Prix      Ville  Surface  Chambres  Sdb  \
# 0  366800    Lanvéoc      150         6   2
# 1  177500    Lanvéoc      330         4   1
# 2  387600     Crozon      160         7   2
# 3  336000     Crozon      130         4   1
# 4  169600  Roscanvel      116         5   1
# 5  798000     morgat      190         6   2
# 6  279470     Crozon       82         2   1
#
#                                           Couverture  \
# 0  https://www.ouestfrance-immo.com/photo-vente-m...
# 1  https://www.ouestfrance-immo.com/photo-vente-m...
# 2  https://www.ouestfrance-immo.com/photo-vente-m...
# 3  https://www.ouestfrance-immo.com/photo-vente-m...
# 4  https://www.ouestfrance-immo.com/photo-vente-m...
# 5  https://www.ouestfrance-immo.com/photo-vente-m...
# 6  https://www.ouestfrance-immo.com/photo-vente-m...
#
#                                                 Lien  Terrain  \
# 0  https://www.ouestfrance-immo.com/immobilier/ve...     8544
# 1  https://www.ouestfrance-immo.com/immobilier/ve...      546
# 2  https://www.ouestfrance-immo.com/immobilier/ve...     2022
# 3  https://www.ouestfrance-immo.com/immobilier/ve...     2000
# 4  https://www.ouestfrance-immo.com/immobilier/ve...     1904
# 5  https://www.ouestfrance-immo.com/immobilier/ve...     1594
# 6  https://www.ouestfrance-immo.com/immobilier/ve...     1265
#
#                                               Photos VueMer         Site
# 0  ["https://www.ouestfrance-immo.com/photo-vente...    Oui  OuestFrance
# 1  ["https://www.ouestfrance-immo.com/photo-vente...    Oui  OuestFrance
# 2  ["https://www.ouestfrance-immo.com/photo-vente...    Oui  OuestFrance
# 3  ["https://www.ouestfrance-immo.com/photo-vente...    Oui  OuestFrance
# 4  ["https://www.ouestfrance-immo.com/photo-vente...    Oui  OuestFrance
# 5  ["https://www.ouestfrance-immo.com/photo-vente...    Oui  OuestFrance
# 6  ["https://www.ouestfrance-immo.com/photo-vente...    Oui  OuestFrance

# %% [markdown]
# ## Agence de la Presqu'ile

# %%
def agence_presquile():

    URL = 'https://www.agencedelapresquile.com/achat-immobilier-crozon/type-1-maison/'
    page = requests.get(URL)

    soup = BeautifulSoup(page.content, 'html.parser')
    results= soup.find_all(class_="btn btn-default")

    fix = "https://www.agencedelapresquile.com"
    all_val = []

    for i in range(1, int(results[1].text)+1):

        URL = 'https://www.agencedelapresquile.com/achat-immobilier-crozon/type-1-maison/'+str(i)
        page = requests.get(URL)

        soup = BeautifulSoup(page.content, 'html.parser')

        results= soup.find_all(class_="block-link")
        link_thumbnail = list(soup.find_all(class_="mainImgLst3"))

        k = 0

        for link in results:

            page = requests.get(fix+link['href'])
            soup = BeautifulSoup(page.content, 'html.parser')
            results2 = soup.find_all(class_="data")

            photos = soup.find_all("img")
            link_photos = []
            for pic in photos:
                if ".jpg" in str(pic) and 'alt=""' in str(pic):
                    link_photos.append(pic['src'][2:])

            values = []

            prix = None
            ville = None
            surf = None
            chb = None
            terr = None

            for info in results2:

                if "Prix du bien" in str(info):
                    prix = int(info.find(class_="valueInfos").text.replace("€", "").strip().replace(" ", ""))
                elif "Ville" in str(info):
                    ville = info.find(class_="valueInfos").text.strip()
                elif "Surface habitable (m²)" in str(info):
                    surf = int(info.find(class_="valueInfos").text.replace("m²", "").strip().replace(" ", ""))
                elif "Nombre de chambre(s)" in str(info):
                    chb = info.find(class_="valueInfos").text.strip()
                elif "surface terrain" in str(info):
                    terr = int(info.find(class_="valueInfos").text.replace("m²", "").strip().replace(" ", ""))

            a_vue_mer = "Non"
            vue_mer = soup.find(itemprop="description").text
            if ("vue" in vue_mer or "bord" in vue_mer) and "mer" in vue_mer:
                a_vue_mer = "Oui"

            all_val.append([prix, ville, surf, chb, None, link_thumbnail[k]['src'][2:], fix+link['href'], terr, link_photos, a_vue_mer])
            k += 1
    df_pi = pd.DataFrame(all_val)
    df_pi.columns=["Prix", "Ville", "Surface", "Chambres", "Sdb", "Couverture", "Lien", "Terrain", "Photos", "VueMer"]
    df_pi['Site'] = "PresquileImmo"
    
    return df_pi

# %%
df_pi = agence_presquile()
df_pi
# Out:
#       Prix   Ville  Surface Chambres   Sdb  \
# 3   https://www.agencedelapresquile.com/296-villa-...   2022.0
# 4   https://www.agencedelapresquile.com/291-ensemb...   3430.0
# 5   https://www.agencedelapresquile.com/289-maison...   1014.0
# 6   https://www.agencedelapresquile.com/285-maison...    570.0
# 7   https://www.agencedelapresquile.com/264-belle-...    793.0
# 8   https://www.agencedelapresquile.com/263-ancien...    701.0
# 9   https://www.agencedelapresquile.com/254-maison...   1678.0
# 10  https://www.agencedelapresquile.com/249-confor...   2139.0
# 11  https://www.agencedelapresquile.com/202-propri...   2020.0
# 12  https://www.agencedelapresquile.com/192-maison...    743.0
# 13  https://www.agencedelapresquile.com/186-belle-...   2510.0
# 14  https://www.agencedelapresquile.com/174-maison...     89.0
# 15  https://www.agencedelapresquile.com/15-maison-...      NaN
#
#                                                Photos VueMer           Site
# 0   ["https://www.ouestfrance-immo.com/photo-vente...    Oui    OuestFrance
# 1   ["https://www.ouestfrance-immo.com/photo-vente...    Oui    OuestFrance
# 2   ["https://www.ouestfrance-immo.com/photo-vente...    Oui    OuestFrance
# 3   ["https://www.ouestfrance-immo.com/photo-vente...    Oui    OuestFrance
# 4   ["https://www.ouestfrance-immo.com/photo-vente...    Oui    OuestFrance
# 5   ["https://www.ouestfrance-immo.com/photo-vente...    Oui    OuestFrance
# 6   ["https://www.ouestfrance-immo.com/photo-vente...    Oui    OuestFrance
# 0   [ag-presquile.staticlbi.com/original/images/bi...    Oui  PresquileImmo
# 1   [ag-presquile.staticlbi.com/original/images/bi...    Oui  PresquileImmo
# 2   [ag-presquile.staticlbi.com/original/images/bi...    Non  PresquileImmo
# 3   [ag-presquile.staticlbi.com/original/images/bi...    Non  PresquileImmo
# 4   [ag-presquile.staticlbi.com/original/images/bi...    Non  PresquileImmo
# 5   [ag-presquile.staticlbi.com/original/images/bi...    Non  PresquileImmo
# 6   [ag-presquile.staticlbi.com/original/images/bi...    Non  PresquileImmo
# 7   [ag-presquile.staticlbi.com/original/images/bi...    Non  PresquileImmo
# 8   [ag-presquile.staticlbi.com/original/images/bi...    Non  PresquileImmo
# 9   [ag-presquile.staticlbi.com/original/images/bi...    Oui  PresquileImmo
# 10  [ag-presquile.staticlbi.com/original/images/bi...    Non  PresquileImmo
# 11  [ag-presquile.staticlbi.com/original/images/bi...    Non  PresquileImmo
# 12  [ag-presquile.staticlbi.com/original/images/bi...    Non  PresquileImmo
# 13  [ag-presquile.staticlbi.com/original/images/bi...    Non  PresquileImmo
# 14  [ag-presquile.staticlbi.com/original/images/bi...    Non  PresquileImmo
# 15  [ag-presquile.staticlbi.com/original/images/bi...    Non  PresquileImmo

# %%
df_concat.columns
# Out:
# Index(['Prix', 'Ville', 'Surface', 'Chambres', 'Sdb', 'Couverture', 'Lien',
#        'Terrain', 'Photos', 'VueMer', 'Site'],
#       dtype='object')

# %% [markdown]
# ## Cabinet Treguer

# %%
URL = 'http://www.cabinet-treguer.fr/advanced-search/page/1/?bedrooms&keyword=29160&max-area&max-price&min-area&status=vente&type=maison'
page = requests.get(URL)
soup = BeautifulSoup(page.content, 'html.parser')
results= soup.find_all("a")
results
# Out:
# [<a href="http://www.cabinet-treguer.fr/">
#  <img alt="logo" src="http://s3.amazonaws.com/aivoni/wp-content/agence165589-images/20190916121923/logo-cabinet-treguer-min.png"/>
#  </a>,
#  <a href="http://www.cabinet-treguer.fr/">Accueil</a>,
#  <a href="http://www.cabinet-treguer.fr/nos-agences-2/">Nos Agences</a>,
#  <a href="http://www.cabinet-treguer.fr/vente/">Vente</a>,
#  <a href="#">Location</a>,
#  <a href="http://www.cabinet-treguer.fr/location-a-lannee/">Location à l’année</a>,
#  <a href="http://www.cabinet-treguer.fr/location-de-vacances/">Location de vacances</a>,
#  <a href="http://www.cabinet-treguer.fr/estimation-immobiliere/">Estimation</a>,
#  <a href="http://www.cabinet-treguer.fr/notre-agence/">Notre équipe</a>,
#  <a href="http://www.cabinet-treguer.fr/biens-vendus/">Biens vendus</a>,
#  <a href="http://www.cabinet-treguer.fr/contact/">Contact</a>,
#  <a href="/wp-admin"><i class="fa fa-user hidden-md hidden-lg"></i> <span class="hidden-sm hidden-xs">Connexion</span></a>,
#  <a href="http://www.cabinet-treguer.fr/">
#  <img alt="Mobile logo" src="http://s3.amazonaws.com/aivoni/wp-content/agence165589-images/
#  <a href="http://www.cabinet-treguer.fr/contact/">Contact</a>,
#  <a href="http://www.cabinet-treguer.fr/mentionslegales/">Mentions Légales</a>,
#  <a href="http://www.cabinet-treguer.fr/acces-vos-donnees-personnelles/">Accès à vos données personnelles</a>,
#  <a href="http://www.cabinet-treguer.fr/cookies/">Cookies</a>,
#  <a href="https://www.instagram.com/aivoni_/" target="_blank">AiVONi</a>,
#  <a href="/wp-admin"><i class="fa fa-user hidden-md hidden-lg"></i> <span class="hidden-sm hidden-xs">Connexion</span></a>,
#  <a class="ctcc-more-info-link" href="http://www.cabinet-treguer.fr/cookies/" tabindex="0" target="_blank">En savoir plus.</a>]

# %%
URL = 'http://www.cabinet-treguer.fr/advanced-search/page/2/?bedrooms&keyword=29160&max-area&max-price&min-area&status=vente&type=maison'

page = requests.get(URL)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
num_pg = []
for val in soup.find(class_="pagination-main").text:
    if val.isdigit():
        num_pg.append(int(val))

num_pg = max(num_pg)
num_pg
# Out:
# 3

# %%
def treguet():
    
    URL = 'http://www.cabinet-treguer.fr/advanced-search/page/1/?bedrooms&keyword=29160&max-area&max-price&min-area&status=vente&type=maison'
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, 'html.parser')

    num_pg = []
    for val in soup.find(class_="pagination-main").text:
        if val.isdigit():
            num_pg.append(int(val))

    num_pg = max(num_pg)
    res  = []
    
    for npage in range(1, num_pg+1):
        
        URL = 'http://www.cabinet-treguer.fr/advanced-search/page/%s/?bedrooms&keyword=29160&max-area&max-price&min-area&status=vente&type=maison'%str(npage)
        page = requests.get(URL)
        soup = BeautifulSoup(page.content, 'html.parser')
    
        results = soup.find_all(class_="btn btn-primary")
        results = results[::2]

        for val in results:


            link = val['href']
            page = requests.get(link)
            soup = BeautifulSoup(page.content, 'html.parser')

            place = soup.find(id="annonce-description")
            city = place.text.strip().split("–")[-1].split()[0].title()

            pic = soup.find_all(class_="sp-image")

            list_pics = []

            for p in pic:
                list_pics.append(p['src'])

            results2 = soup.find_all(class_="text-right")

            price = int(soup.find("strong").text.replace(" €", "").replace(".", ""))
            vue_mer = soup.find(id="descriptionblockxs").text

            to_ret = "Non"

            if ("vue" in vue_mer or "bord" in vue_mer) and "mer" in vue_mer:
                to_ret="Oui"

            feat = []
            for elem in results2[:4]:
                if str(elem.text) != "":
                    feat.append(int(elem.text.replace(" m²", "")))

            feat.append(price)
            feat.append(city)
            feat.append(link)
            feat.append(list_pics)
            feat.append(to_ret)

            res.append(feat)
    df=pd.DataFrame(res)
    df.columns=["Surface", "Terrain", "Chambres", "Prix", "Ville", "Lien", "Photos", "VueMer"]
    df['Site'] = "Treguer"
    df['Couverture'] = df['Photos'].apply(lambda x: x[0])
    
    df = df.reindex(['Prix', 'Ville', 'Surface', 'Chambres', 'Couverture', 'Lien',
       'Terrain', 'Photos', 'VueMer', 'Site'], axis=1)
        
    return df

# %%
df_treguet = treguet()
df_treguet
# Out:
#     Surface  Terrain  Chambres     Prix    Ville  \
# 0       300     2022         4   399000   Crozon
# 1       261     2006         8   798000   Crozon
# 2       130     2000         4   336000   Crozon
# 3       200     1400         6  1260000   Crozon
# 4       100     1203         2   197950  Lanveoc
# 5       121     2212         5   420000   Crozon
# 6       148     2400         4   840000   Crozon
# 7        97      884         4   129600   Crozon
# 8       162     1182         4   181900   Crozon
# 9        70     1026         2   135000   Crozon
# 10      150     1724         4   239625   Crozon
# 11      409     7600         4   892500   Crozon
# 12       70      126         2   100000  Lanveoc
# 13      135      604         4   336000   Crozon
# 14      152      603         5   420000   Crozon
# 15      100      546         3   263750   Crozon
# 16      180     1700         4   294000  Lanveoc
# 17      130     1882         3   263750   Morgat
# 18      100     1394         3   223650   Crozon
# 19      121     3500         4   450450   Crozon
# 20      100      770         3   192600   Crozon
# 21      160     4680         4   254400   Crozon
# 22      133      599         4   525000   Crozon
#
#                                                  Lien  \
# 0   http://www.cabinet-treguer.fr/property/maison-...
# 1   http://www.cabinet-treguer.fr/property/maison-...
# 2   http://www.cabinet-treguer.fr/property/maison-...
# 3   http://www.cabinet-treguer.fr/property/maison-...
# 4   http://www.cabinet-treguer.fr/property/maison-...
# 5   http://www.cabinet-treguer.fr/property/maison-...
# 6   http://www.cabinet-treguer.fr/property/maison-...
# 7   http://www.cabinet-treguer.fr/property/maison-...
# 8   http://www.cabinet-treguer.fr/property/maison-...
# 9   http://www.cabinet-treguer.fr/property/maison-...
# 10  http://www.cabinet-treguer.fr/property/maison-...
# 11  http://www.cabinet-treguer.fr/property/maison-...
# 12  http://www.cabinet-treguer.fr/property/maison-...
# 13  http://www.cabinet-treguer.fr/property/maison-...
# 14  http://www.cabinet-treguer.fr/property/maison-...
# 15  http://www.cabinet-treguer.fr/property/maison-...
# 16  http://www.cabinet-treguer.fr/property/maison-...
# 17  http://www.cabinet-treguer.fr/property/maison-...
# 18  http://www.cabinet-treguer.fr/property/maison-...
# 19  http://www.cabinet-treguer.fr/property/maison-...
# 20  http://www.cabinet-treguer.fr/property/maison-...
# 21  http://www.cabinet-treguer.fr/property/maison-...
# 22  http://www.cabinet-treguer.fr/property/maison-...
#
#                                                Photos VueMer     Site  \
# 0   [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 1   [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 2   [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 3   [http://s3.amazonaws.com/aivoni/wp-content/age...    Oui  Treguer
# 4   [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 5   [http://s3.amazonaws.com/aivoni/wp-content/age...    Oui  Treguer
# 6   [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 7   [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 8   [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 9   [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 10  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 11  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 12  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 13  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 14  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 15  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 16  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 17  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 18  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 19  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 20  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 21  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 22  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
#
#                                            Couverture
# 0   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 1   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 2   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 3   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 4   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 5   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 6   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 7   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 8   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 9   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 10  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 11  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 12  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 13  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 14  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 15  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 16  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 17  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 18  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 19  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 20  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 21  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 22  http://s3.amazonaws.com/aivoni/wp-content/agen...

# %%
df_treguet = df_treguet.reindex(['Prix', 'Ville', 'Surface', 'Chambres', 'Couverture', 'Lien',
       'Terrain', 'Photos', 'VueMer', 'Site'], axis=1)
# Out:
#        Prix    Ville  Surface  Chambres  \
# 0    399000   Crozon      300         4
# 1    798000   Crozon      261         8
# 2    336000   Crozon      130         4
# 3   1260000   Crozon      200         6
# 4    197950  Lanveoc      100         2
# 5    420000   Crozon      121         5
# 6    840000   Crozon      148         4
# 7    129600   Crozon       97         4
# 8    181900   Crozon      162         4
# 9    135000   Crozon       70         2
# 10   239625   Crozon      150         4
# 11   892500   Crozon      409         4
# 12   100000  Lanveoc       70         2
# 13   336000   Crozon      135         4
# 14   420000   Crozon      152         5
# 15   263750   Crozon      100         3
# 16   294000  Lanveoc      180         4
# 17   263750   Morgat      130         3
# 18   223650   Crozon      100         3
# 19   450450   Crozon      121         4
# 20   192600   Crozon      100         3
# 21   254400   Crozon      160         4
# 22   525000   Crozon      133         4
#
#                                            Couverture  \
# 0   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 1   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 2   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 3   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 4   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 5   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 6   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 7   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 8   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 9   http://s3.amazonaws.com/aivoni/wp-content/agen...
# 10  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 11  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 12  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 13  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 14  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 15  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 16  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 17  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 18  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 19  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 20  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 21  http://s3.amazonaws.com/aivoni/wp-content/agen...
# 22  http://s3.amazonaws.com/aivoni/wp-content/agen...
#
#                                                  Lien  Terrain  \
# 0   http://www.cabinet-treguer.fr/property/maison-...     2022
# 1   http://www.cabinet-treguer.fr/property/maison-...     2006
# 2   http://www.cabinet-treguer.fr/property/maison-...     2000
# 3   http://www.cabinet-treguer.fr/property/maison-...     1400
# 4   http://www.cabinet-treguer.fr/property/maison-...     1203
# 5   http://www.cabinet-treguer.fr/property/maison-...     2212
# 6   http://www.cabinet-treguer.fr/property/maison-...     2400
# 7   http://www.cabinet-treguer.fr/property/maison-...      884
# 8   http://www.cabinet-treguer.fr/property/maison-...     1182
# 9   http://www.cabinet-treguer.fr/property/maison-...     1026
# 10  http://www.cabinet-treguer.fr/property/maison-...     1724
# 11  http://www.cabinet-treguer.fr/property/maison-...     7600
# 12  http://www.cabinet-treguer.fr/property/maison-...      126
# 13  http://www.cabinet-treguer.fr/property/maison-...      604
# 14  http://www.cabinet-treguer.fr/property/maison-...      603
# 15  http://www.cabinet-treguer.fr/property/maison-...      546
# 16  http://www.cabinet-treguer.fr/property/maison-...     1700
# 17  http://www.cabinet-treguer.fr/property/maison-...     1882
# 18  http://www.cabinet-treguer.fr/property/maison-...     1394
# 19  http://www.cabinet-treguer.fr/property/maison-...     3500
# 20  http://www.cabinet-treguer.fr/property/maison-...      770
# 21  http://www.cabinet-treguer.fr/property/maison-...     4680
# 22  http://www.cabinet-treguer.fr/property/maison-...      599
#
#                                                Photos VueMer     Site
# 0   [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 1   [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 2   [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 3   [http://s3.amazonaws.com/aivoni/wp-content/age...    Oui  Treguer
# 4   [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 5   [http://s3.amazonaws.com/aivoni/wp-content/age...    Oui  Treguer
# 6   [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 7   [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 8   [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 9   [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 10  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 11  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 12  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 13  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 14  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 15  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 16  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 17  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 18  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 19  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 20  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 21  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
# 22  [http://s3.amazonaws.com/aivoni/wp-content/age...    Non  Treguer
